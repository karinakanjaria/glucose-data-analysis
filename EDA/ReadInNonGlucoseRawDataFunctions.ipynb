# %% [markdown]
# ### Read In Non-Glucose Raw Data Files

# %%
import pandas as pd
import json

# %%
def readCohortData(): 
    return pd.read_csv("../../cephfs/data/cohort.csv")

# %%
def readGlucoseDataDictionary():    
    with open("../../cephfs/data/glucose.json") as json_data:
        return json.load(json_data)

# %%
with open("../../cephfs/data/glucose_records.json") as json_data:
    data = json.load(json_data)
    data = pd.DataFrame.from_records(data)

# %%
data
# Out:
#                                                   key  \
# 0   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 1   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 2   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 3   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 4   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 5   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 6   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 7   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 8   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 9   g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 10  g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 11  g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 12  g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 13  g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 14  g5-datascience-prod-1-197420.cgm_did.glucose_r...
# 15  g5-datascience-prod-1-197420.cgm_did.glucose_r...
# ...
